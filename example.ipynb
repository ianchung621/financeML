# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Load Data
#
# prototype:
# - event_df (N, d): df with col 'date' and 'stock_id', each row represent an event (a sample for ML task)
# - signal_df (T, S): df with idx: date and stock_id, time series for each asset

# %%
close_df = pd.read_csv('data/public/close.csv', index_col='date', parse_dates=['date'])
event_df = pd.read_csv('data/public/toydata.csv', 
            parse_dates=['date'], dtype={'stock_id':close_df.columns.dtype}).drop(columns='contract_name')
event_df
# Out:
#              date stock_id  contract_buy_top5_volume  \
# 0      2021-05-10     1102                      1032
# 1      2021-05-10     1210                       107
# 2      2021-05-10     1303                      2426
# 3      2021-05-10     1319                        48
# 4      2021-05-10     1326                       504
# ...           ...      ...                       ...
# 206447 2025-05-08     8086                       323
# 206448 2025-05-08     8112                        83
# 206449 2025-05-08     8358                       237
# 206450 2025-05-08     8436                        51
# 206451 2025-05-08     9914                       138
#
#         contract_sell_top5_volume  contract_total_volume  ii_fii_volume  \
# 0                            1386                   1502        1951547
# 1                             197                    225          78847
# 2                            3917                   4061        4224839
# ...

# %%
close_df
# Out:
#                  1101       1102      1210      1216      1301       1303  \
# date
# 2021-05-10  41.987507  39.651203  48.36136  67.00047  89.73001  74.293550
# 2021-05-11  40.955677  39.028000  47.32219  66.55499  86.76723  71.705795
# 2021-05-12  39.368248  37.820545  44.28462  64.68397  81.01096  67.448530
# 2021-05-13  39.050762  37.353146  45.08398  64.77306  79.82585  65.945960
# 2021-05-14  39.368248  38.171097  45.08398  66.10951  80.84166  67.114624
# ...               ...        ...       ...       ...       ...        ...
# 2025-05-02  29.950000  44.850000  59.70000  78.10000  34.80000  30.850000
# 2025-05-05  30.600000  45.550000  62.80000  80.80000  36.10000  31.600000
# 2025-05-06  30.550000  45.650000  61.80000  80.70000  36.20000  31.800000
# 2025-05-07  30.850000  45.700000  62.90000  80.70000  36.70000  31.800000
# 2025-05-08  30.550000  45.050000  62.70000  80.70000  35.65000  30.950000
#
# ...

# %%
# The dtype of date, stock_id in event_df must match with close_df's idx (date), col (stock_id)
print(f'event_df info: \n')
event_df.info()
print(f'close_df idx (date) dtype: {close_df.index.dtype}')
print(f'close_df col (stock_id) dtype: {close_df.columns.dtype}')
# Out:
# event_df info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206452 entries, 0 to 206451
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   date                       206452 non-null  datetime64[ns]
#  1   stock_id                   206452 non-null  object
#  2   contract_buy_top5_volume   206452 non-null  int64
#  3   contract_sell_top5_volume  206452 non-null  int64
#  4   contract_total_volume      206452 non-null  int64
#  5   ii_fii_volume              206452 non-null  int64
#  6   ii_trust_volume            206452 non-null  int64
#  7   ii_dealer_volume           206452 non-null  int64
#  8   revenue                    206452 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 14.2+ MB
# close_df idx (date) dtype: datetime64[ns]
# close_df col (stock_id) dtype: object
